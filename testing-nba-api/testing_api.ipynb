# %%
# %pip install nba_api
# %pip install pandas
import pandas as pd


from nba_api.stats.endpoints import playercareerstats # gets all data from players
from nba_api.stats.static import players # static demographic table for players

# Anthony Davis


#players = pd.DataFrame(career)


nba_players = players.get_players()
player_i = pd.DataFrame(nba_players)
# need a way to call all the player id
career = playercareerstats.PlayerCareerStats(player_id = "203076")
career = career.get_data_frames()[0]
#print(player_i)
#print(career)

print (pd.merge(career, player_i, left_on='PLAYER_ID', right_on='id', how='left'))
# Out:
# Requirement already satisfied: nba_api in ./.venv/lib/python3.13/site-packages (1.6.1)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in ./.venv/lib/python3.13/site-packages (from nba_api) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in ./.venv/lib/python3.13/site-packages (from nba_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203076   2012-13        00  1610612740               NOH        20.0
# 1      203076   2013-14        00  1610612740               NOP        21.0
# 2      203076   2014-15        00  1610612740               NOP        22.0
# 3      203076   2015-16        00  1610612740               NOP        23.0
# 4      203076   2016-17        00  1610612740               NOP        24.0
# 5      203076   2017-18        00  1610612740               NOP        25.0
# 6      203076   2018-19        00  1610612740               NOP        26.0
# 7      203076   2019-20        00  1610612747               LAL        27.0
# 8      203076   2020-21        00  1610612747               LAL        28.0
# 9      203076   2021-22        00  1610612747               LAL        29.0
# 10     203076   2022-23        00  1610612747               LAL        30.0
# 11     203076   2023-24        00  1610612747               LAL        31.0
# 12     203076   2024-25        00  1610612747               LAL        31.0
#
#     GP  GS     MIN  FGM  ...  STL  BLK  TOV   PF   PTS      id      full_name  \
# 0   64  60  1846.0  349  ...   75  112   89  158   867  203076  Anthony Davis
# 1   67  66  2358.0  522  ...   89  189  109  200  1394  203076  Anthony Davis
# 2   68  68  2455.0  642  ...  100  200   95  141  1656  203076  Anthony Davis
# 3   61  61  2164.0  560  ...   78  125  121  148  1481  203076  Anthony Davis
# 4   75  75  2708.0  770  ...   94  167  181  168  2099  203076  Anthony Davis
# 5   75  75  2727.0  780  ...  115  193  162  159  2110  203076  Anthony Davis
# 6   56  56  1850.0  530  ...   88  135  112  132  1452  203076  Anthony Davis
# 7   62  62  2131.0  551  ...   91  143  154  156  1618  203076  Anthony Davis
# 8   36  36  1162.0  301  ...   45   59   74   60   786  203076  Anthony Davis
# 9   40  40  1404.0  370  ...   49   90   82   97   927  203076  Anthony Davis
# 10  56  54  1905.0  542  ...   59  114  122  146  1451  203076  Anthony Davis
# 11  76  76  2700.0  713  ...   91  178  159  177  1876  203076  Anthony Davis
# 12  20  20   708.0  199  ...   25   39   39   40   556  203076  Anthony Davis
#
#     first_name  last_name  is_active
# 0      Anthony      Davis       True
# 1      Anthony      Davis       True
# 2      Anthony      Davis       True
# 3      Anthony      Davis       True
# 4      Anthony      Davis       True
# 5      Anthony      Davis       True
# 6      Anthony      Davis       True
# 7      Anthony      Davis       True
# 8      Anthony      Davis       True
# 9      Anthony      Davis       True
# 10     Anthony      Davis       True
# 11     Anthony      Davis       True
# 12     Anthony      Davis       True
#
# [13 rows x 32 columns]
